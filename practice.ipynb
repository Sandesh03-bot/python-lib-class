# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading and inspecting data

# %%
data = pd.read_csv('netflix_titles.csv') # loading the data
data.head() # Seeing the first 5 rows
data.isnull().sum() # Checking the null values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Basic statistics

# %%
# data["Feature1"].mean() # Find mean of a specific column
# data.mean(numeric_only=True) # Finding mean of numeric type column only for which we use numeric_only = True inside .mean() meathod

#---------> Same work for sum min max meadian std count  <--------

# data["Feature1"].sum()
# data.sum(numeric_only=True)

# data["Feature1"].median()
# data.median(numeric_only=True)

# data["Feature1"].min()
# data.min(numeric_only=True)

# data["Feature1"].max()
# data.max(numeric_only=True)

# data["Feature1"].count()
# data.count(numeric_only=True)
# Out:
# Feature1       99.000000
# Feature2        1.497998
# Feature3        3.422062
# Feature5        1.000000
# Feature6     1543.622087
# Feature7        8.843108
# Feature8       22.813462
# Feature9        9.915071
# Feature10      14.060631
# Feature11      46.000000
# Feature13       2.000000
# Feature16      17.012344
# Feature17      14.999633
# dtype: float64

# %% [markdown]
# ## Filtering Data

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   str
#  1   type          8807 non-null   str
#  2   title         8807 non-null   str
#  3   director      6173 non-null   str
#  4   cast          7982 non-null   str
#  5   country       7976 non-null   str
#  6   date_added    8797 non-null   str
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   str
#  9   duration      8804 non-null   str
#  10  listed_in     8807 non-null   str
#  11  description   8807 non-null   str
# dtypes: int64(1), str(11)
# memory usage: 825.8 KB
