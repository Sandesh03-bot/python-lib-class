# %% [markdown]
# Load dataset \
# ↓\
# Inspect dataset\
# ↓\
# Clean data\
# ↓\
# Analyze data\
# ↓\
# Visualize patterns\
# ↓\
# Write insights

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading and inspecting data

# %% [markdown]
# df.shape
# df.columns
# df.dtypes
# df.info()
# df.describe()
# df.head()
# df.tail()
# df.isnull().sum()
# df.duplicated().sum()

# %%
data = pd.read_csv('netflix_titles.csv') # loading the data

# attributes and methods to inspect data

# data.head() # Seeing the first 5 rows
# data.tail() # Seeing the last 5 rows
# data.shape # Checking the shape of the data  ==>(rows, columns)
# data.columns # Checking the columns in the data
# data.info() # Getting the info about the data
# data.dtypes # Checking the data types of the columns
# data.values # Getting the values of the data in array format
# data.describe() # Getting the statistical summary of the data
# data.sample(5) # Getting a random sample of 5 rows

# %%
# attributes and methods to clean data

# data.isnull() # detect missing values in the data
# data.notnull() # Detect non-missing values
# data.dropna() # Remove missing values  #directly removes the rows with missing values
# data.fillna('Unknown') # Fill missing values with 'Unknown'      
# data.duplicated() # Detect duplicates in the data
# data.drop_duplicates() # Remove duplicates from the data           
# data.replace('TV-MA', 'Mature') # Replace values in the data              
# data.astype({'release_year': 'str'}) # Change datatype of 'release_year' to string
# data.rename(columns={'release_year': 'Release Year'}, inplace=True) # Rename column 'release_year' to 'Release Year'               
# data.drop(columns=['rating'], inplace=True) # Remove the 'rating' column from the data # inplace=True modifies the original data frame instead of creating a new one
# data.interpolate() # Fill missing values mathematically
